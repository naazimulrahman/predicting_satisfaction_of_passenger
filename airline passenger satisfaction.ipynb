# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/train.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
data.shape
# Out:
# (103904, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
data['Arrival Delay in Minutes'] = data['Arrival Delay in Minutes'].mean()

# %%
data.drop(columns=['Unnamed: 0','id'], inplace=True)

# %%
x = data.iloc[ : , :-1]
y = data.iloc[ : , -1]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 103904 entries, 0 to 103903
# Series name: satisfaction
# Non-Null Count   Dtype
# --------------   -----
# 103904 non-null  object
# dtypes: object(1)
# memory usage: 811.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
y = label.fit_transform(y)
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
categories = x.select_dtypes(include=['object']).columns.tolist()
categories
# Out:
# ['Gender', 'Customer Type', 'Type of Travel', 'Class']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
transformer = ColumnTransformer([
    ('encoder', OneHotEncoder(handle_unknown='ignore', drop="first"), categories),
], remainder=MinMaxScaler())
x = transformer.fit_transform(x)
x
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 1.00000000e+00, ...,
#         1.00000000e+00, 1.57035176e-02, 0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         2.00000000e-01, 6.28140704e-04, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [1.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         8.00000000e-01, 4.39698492e-03, 0.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         2.00000000e-01, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.00000000e-01, 0.00000000e+00, 0.00000000e+00]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((83123, 23), (20781, 23), (83123,), (20781,))

# %%
# !pip install tensorflow

# %%
import tensorflow
from tensorflow import keras
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Dense, Input ,Dropout ,BatchNormalization

# %%
model = Sequential()
model.add(Input(shape=(x_train.shape[1],)))
model.add(BatchNormalization())
model.add(Dense(64, activation="relu",  kernel_initializer="glorot_uniform",kernel_regularizer=l2(0.03),name="layer1"))
model.add(Dropout(rate=0.1))
model.add(Dense(32, activation="relu", kernel_initializer="glorot_uniform", name="layer2"))
model.add(Dense(1, activation="sigmoid", name="layer3"))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  batch_normalization_1 (Bat  (None, 23)                92
#  chNormalization)
#
#  layer1 (Dense)              (None, 64)                1536
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  layer2 (Dense)              (None, 32)                2080
#
#  layer3 (Dense)              (None, 1)                 33
#
# ...
# Total params: 3741 (14.61 KB)
# Trainable params: 3695 (14.43 KB)
# Non-trainable params: 46 (184.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(x_train, y_train, validation_data =(x_test, y_test), batch_size = 32, epochs = 10)
# Out:
# Epoch 1/10
# 2598/2598 [==============================] - 15s 5ms/step - loss: 0.3151 - accuracy: 0.9024 - val_loss: 0.1880 - val_accuracy: 0.9369
# Epoch 2/10
# 2598/2598 [==============================] - 15s 6ms/step - loss: 0.2153 - accuracy: 0.9200 - val_loss: 0.1710 - val_accuracy: 0.9432
# Epoch 3/10
# 2598/2598 [==============================] - 14s 5ms/step - loss: 0.2019 - accuracy: 0.9254 - val_loss: 0.1542 - val_accuracy: 0.9438
# Epoch 4/10
# 2598/2598 [==============================] - 15s 6ms/step - loss: 0.1967 - accuracy: 0.9276 - val_loss: 0.1519 - val_accuracy: 0.9485
# Epoch 5/10
# 2598/2598 [==============================] - 8s 3ms/step - loss: 0.1907 - accuracy: 0.9289 - val_loss: 0.1444 - val_accuracy: 0.9482
# Epoch 6/10
# 2598/2598 [==============================] - 8s 3ms/step - loss: 0.1853 - accuracy: 0.9314 - val_loss: 0.1396 - val_accuracy: 0.9505
# Epoch 7/10
# ...

# %%
metrics = pd.DataFrame(history.history)
metrics[["loss","val_loss"]].plot();
metrics[["accuracy","val_accuracy"]].plot();

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
# Out:
# 650/650 [==============================] - 1s 1ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[11342,   428],
#        [  539,  8472]])

# %% [markdown]
# # Hyperparameter Tunning

# %%
# !pip install keras-tuner

# %%
import keras_tuner as kt

# %%
def build_model(hp):
    """

    Args:
      hp:

    Returns:

    """
    model = Sequential()
    counter =0
    for i in range(hp.Int('num_layers', min_value = 2, max_value =20)):
      if counter == 0:

        model.add(
            Dense(
                units = hp.Int('units_' + str(i), min_value = 32, max_value =512, step = 32),
                activation = hp.choice('activation_' + str(i), values = ['relu', 'tanh','sigmoid']),
                input_dim = x_train.shape[1]
            )
        )
      else:
        model.add(
            Dense(
                units = hp.Int('units_' + str(i), min_value = 32, max_value =512, step = 32),
                activation = hp.choice('activation_' + str(i), values = ['relu', 'tanh','sigmoid'])
            )
        )
      counter+=1
    model.add(Dense(1, activation='sigmoid'))
    # The following line was indented too far, causing the error.
    model.compile(
        optimizer=hp.Choice('optimizer', values = ['adam', 'rmsprop', 'sgd']),
        loss=hp.Choice('loss', values = ['binary_crossentropy', 'mean_squared_error']),
        metrics=['accuracy']
    )
    return model

# %%
tuner=kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory='kt_dir',
    project_name='nazoo'
)

# %%
tuner.search(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
